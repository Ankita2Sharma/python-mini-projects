# %%
a =  none
bool(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-798c5629507e> in <cell line: 1>()
# ----> 1 a =  none
#       2 bool(a)
#
# NameError: name 'none' is not defined

# %%
bool = True
print(int(bool)
# Out:
#   File "<ipython-input-3-37c1fbcb23f7>", line 2
#     print(int(bool)
#                    ^
# SyntaxError: incomplete input

# %% [markdown]
# #string

# %%
lang1 = "python"
lang2 ="python"

# %%
lang1==lang2
# Out:
# True

# %%
my_text='''
giuygdouisduh
ugirghe
frgr

'''

# %%
print(my_text)
# Out:
# giuygdouisduh
# ugirghe
# frgr

# %%
a ='5'
b = '5'

print(a+b)
# Out:
# 55

# %%
a ='5'
b = 5

print(a*b)
# Out:
# 55555

# %%
# Function defination my_add_fn that adds two numbers and returns the value

def my_add_fn(a,b):
  return cby(a)+b

a = input("Enter 1st number: ")

b = input("Enter 2nd number: ")

result = my_add_fn(a,b)

print(result)
# Out:
# Enter 1st number: 4
# Enter 2nd number: 7
# 47
