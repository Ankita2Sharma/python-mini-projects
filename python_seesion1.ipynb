# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankita2Sharma/python-mini-projects/blob/master/python_seesion1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Python")
# Out:
# Hello Python

# %%
print(2**10)
# Out:
# 1024

# %%
 a=8
 b=6
 result = a+b
 print(result)
# Out:
# 14

# %%
5//2
# Out:
# 2

# %%
2**3
# Out:
# 8

# %%
5%2
# Out:
# 1

# %%
#dynamically typed language
a = "2.0"
type(a)
# Out:
# str

# %%
a = False
type(a)
# Out:
# bool

# %%
# case sensitive language
a=2
b=3
A =4
result1 = a+3
result2 = A+3
print(result1)
print(result2)
# Out:
# 5
# 7

# %%
x = 3
y=4
r=1
dist = (x**2+y**2)**0.5-r
print(dist)
# Out:
# 4.0

# %%
#function
#strict formatting is required in python


def calculate_dist(x,y,r):
  dist = (x**2+y**2)**0.5-r
  return dist

# %%
calculate_dist(3,5,1)
# Out:
# 4.830951894845301

# %%
import math
math.hypot(3,4)-1
# Out:
# 4.0

# %%
import math
def calculated_dist(x,y,r):
  #dist = (x**2+y**2)**0.5-r
  result3 =  math.hypot(x,y)-r
  return result3

# %%
calculated_dist(3,5,1)
# Out:
# 4.830951894845301

# %%
a1 = 4
type(a1)
# Out:
# int

# %%
a0 = float(4)
type(a0)
# Out:
# float

# %%
temp = float("4")
type(temp)
# Out:
# float

# %%
temp = float("abc")
type(temp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-c255a09da34a> in <cell line: 1>()
# ----> 1 temp = float("abc")
#       2 type(temp)
#
# ValueError: could not convert string to float: 'abc'

# %%
4/2
# Out:
# 2.0

# %%
X = input("Enter a x co-ordinate : ")
Y = input("Enter a y co-ordinate : ")
r = input("Enter a r co-ordinate : ")

print(type(X),type(Y),type(r))

calculated_dist(X,Y,r)
# Out:
# Enter a x co-ordinate : 3
# Enter a y co-ordinate : 4
# Enter a r co-ordinate : 1
# <class 'str'> <class 'str'> <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-d0fe137e961e> in <cell line: 7>()
#       5 print(type(X),type(Y),type(r))
#       6
# ----> 7 calculated_dist(X,Y,r)
#
# <ipython-input-19-f9c17e7e820c> in calculated_dist(x, y, r)
#       2 def calculated_dist(x,y,r):
#       3   #dist = (x**2+y**2)**0.5-r
# ----> 4   result3 =  math.hypot(x,y)-r
#       5   return result3
#
# TypeError: must be real number, not str

# %%
X = float(input("Enter a x co-ordinate : "))
Y = float(input("Enter a y co-ordinate : "))
r = float(input("Enter a r co-ordinate : "))

print(type(X),type(Y),type(r))

calculated_dist(X,Y,r)
# Out:
# Enter a x co-ordinate : 3
# Enter a y co-ordinate : 4
# Enter a r co-ordinate : 2
# <class 'float'> <class 'float'> <class 'float'>
# 3.0

# %%
 c = 5
 d=7
 temp = c
 c=d
 d =temp
 print(c,d)
# Out:
# 7 5

# %%
 c = 5
 d=7
 temp = c
 c,d = d,c
 d =temp
 print(c,d)
# Out:
# 7 5

# %%
#loops
#for loop
#while loop
# do-while loop

# %%
for i in range(5):
  print(i,"Ankita")
# Out:
# 0 Ankita
# 1 Ankita
# 2 Ankita
# 3 Ankita
# 4 Ankita

# %%
while (5<3):
  print("Ankita")
# Out:
# Streaming output truncated to the last 5000 lines.
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# Ankita
# ...
